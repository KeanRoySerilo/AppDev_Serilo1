# %% [markdown]
# **Exercise 1**

# %%
print('Hello world!')
#upper case p changed to lower case

# %%
print('Hello world!')
#missing open bracket

# %%
print('Hello world!')
#missing single quotation mark on the end

# %%
print('Hello world!')
#has an extra single quotation mark

# %% [markdown]
# **Exercise 2**

# %%
x = 43
x = x + 1
print(x)
#44 because x(43) + 1 = 44

# %% [markdown]
# **Exercise 3**

# %%
x = 43
x = x + 1
print(x)
#the upper case X on the second line changed to lower case
